# %%
import pandas as pd
import numpy as np

# %%
# object creation
S = pd.Series([1,2,3,4,5])
S
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dates = pd.date_range ("20220101", periods =10)
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df =pd.DataFrame(np.random.randn(10,4), columns=list("LALU"))
df
# Out:
#           L         A         L         U
# 0 -0.392622  0.843422  0.101202 -1.061907
# 1 -0.404271  0.599379 -0.131306  0.081315
# 2 -0.980483  1.750748 -2.344604  0.570129
# 3 -0.264422  0.753402  1.986988 -0.927564
# 4  0.552012 -1.661716 -0.043985 -1.701020
# 5  1.342485 -0.719345 -1.631878 -2.185780
# 6  0.305403 -0.161625  0.895818  0.267837
# 7 -1.416656 -0.432468 -0.826268 -1.148109
# 8  1.752380  1.826531  0.874805  0.982452
# 9 -0.348348  0.610045  0.725340  0.318048

# %%
df2 = pd.DataFrame (
    {
    "A":1.0,
    "B":pd.Timestamp("20130102"),
    "C":pd.Series(1, index=list(range(4)), dtype="float32"),
    "D":pd.Categorical (["girl", "train", "test", "train"]),
    "F":"Females",
}
)
df2
# Out:
#      A          B    C      D        F
# 0  1.0 2013-01-02  1.0   girl  Females
# 1  1.0 2013-01-02  1.0  train  Females
# 2  1.0 2013-01-02  1.0   test  Females
# 3  1.0 2013-01-02  1.0  train  Females

# %%
df5 = pd.DataFrame ( 
    {
    "A":1.0,
    "B":pd.Timestamp("20130102"),
    "C":pd.Series(1, index=list(range(4)), dtype="float32"),
    "D":pd.Categorical (["girl", "women", "test", "truck"]),
    "F":"Females",
}
)   

print(df5)
# Out:
#      A          B    C      D        F
# 0  1.0 2013-01-02  1.0   girl  Females
# 1  1.0 2013-01-02  1.0  women  Females
# 2  1.0 2013-01-02  1.0   test  Females
# 3  1.0 2013-01-02  1.0  truck  Females

# %%
mport pandas as pd
Load = pd.read_csv ("FAOSTAT_data_1-12-2022.csv")
Loadi
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 0           FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 3           FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 5           FS  Suite of Food Security Indicators        165  Pakistan
# 6           FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# 9           FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
Load.tail(2)
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 17          FS  Suite of Food Security Indicators        165  Pakistan
# 18          FS  Suite of Food Security Indicators        165  Pakistan
#
#     Element Code Element  Item Code  \
# 17          6132   Value     210011
# 18          6132   Value     210011
#
#                                                  Item  Year Code       Year  \
# 17  Number of people undernourished (million) (3-y...   20172019  2017-2019
# 18  Number of people undernourished (million) (3-y...   20182020  2018-2020
#
#         Unit  Value Flag Flag Description  Note
# 17  millions   25.8    F     FAO estimate   NaN
# 18  millions   27.9    F     FAO estimate   NaN

# %%
import pandas as pd
Load = pd.read_csv ("FAOSTAT_data_1-12-2022.csv",header=None)
Load
# Out:
#              0                                  1          2         3   \
# 0   Domain Code                             Domain  Area Code      Area
# 1            FS  Suite of Food Security Indicators        165  Pakistan
# 2            FS  Suite of Food Security Indicators        165  Pakistan
# 3            FS  Suite of Food Security Indicators        165  Pakistan
# 4            FS  Suite of Food Security Indicators        165  Pakistan
# 5            FS  Suite of Food Security Indicators        165  Pakistan
# 6            FS  Suite of Food Security Indicators        165  Pakistan
# 7            FS  Suite of Food Security Indicators        165  Pakistan
# 8            FS  Suite of Food Security Indicators        165  Pakistan
# 9            FS  Suite of Food Security Indicators        165  Pakistan
# 10           FS  Suite of Food Security Indicators        165  Pakistan
# 11           FS  Suite of Food Security Indicators        165  Pakistan
# ...
